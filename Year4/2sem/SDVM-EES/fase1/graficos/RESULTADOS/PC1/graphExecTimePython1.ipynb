# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 

columns = ['Language', 'Program', 'PowerLimit', 'Package', 'Core(s)', 'GPU', 'DRAM', 'Time (ms)', 'Temperature', 'Memory']

powercap_1 =  'pc1/_async_tree_cpu_io_mixed_PowerLimit___1.csv'
powercap_12 = 'pc1/_async_tree_cpu_io_mixed_PowerLimit__12.csv'
powercap_15 = 'pc1/_async_tree_cpu_io_mixed_PowerLimit__15.csv'
powercap_25 = 'pc1/_async_tree_cpu_io_mixed_PowerLimit__25.csv'
powercap_47 = 'pc1/_async_tree_cpu_io_mixed_PowerLimit__47.csv'
powercap_55 = 'pc1/_async_tree_cpu_io_mixed_PowerLimit__55.csv'

powercap2_1 =  'pc1/_async_tree_PowerLimit___1.csv'
powercap2_12 = 'pc1/_async_tree_PowerLimit__12.csv'
powercap2_15 = 'pc1/_async_tree_PowerLimit__15.csv'
powercap2_25 = 'pc1/_async_tree_PowerLimit__25.csv'
powercap2_47 = 'pc1/_async_tree_PowerLimit__47.csv'
powercap2_55 = 'pc1/_async_tree_PowerLimit__55.csv'

powercap3_1 =  'pc1/_chameleon_PowerLimit___1.csv'
powercap3_12 = 'pc1/_chameleon_PowerLimit__12.csv'
powercap3_15 = 'pc1/_chameleon_PowerLimit__15.csv'
powercap3_25 = 'pc1/_chameleon_PowerLimit__25.csv'
powercap3_47 = 'pc1/_chameleon_PowerLimit__47.csv'
powercap3_55 = 'pc1/_chameleon_PowerLimit__55.csv'

powercap4_1 =  'pc1/_django_template_PowerLimit___1.csv'
powercap4_12 = 'pc1/_django_template_PowerLimit__12.csv'
powercap4_15 = 'pc1/_django_template_PowerLimit__15.csv'
powercap4_25 = 'pc1/_django_template_PowerLimit__25.csv'
powercap4_47 = 'pc1/_django_template_PowerLimit__47.csv'
powercap4_55 = 'pc1/_django_template_PowerLimit__55.csv'

powercap5_1 =  'pc1/_docutils_PowerLimit___1.csv'
powercap5_12 = 'pc1/_docutils_PowerLimit__12.csv'
powercap5_15 = 'pc1/_docutils_PowerLimit__15.csv'
powercap5_25 = 'pc1/_docutils_PowerLimit__25.csv'
powercap5_47 = 'pc1/_docutils_PowerLimit__47.csv'
powercap5_55 = 'pc1/_docutils_PowerLimit__55.csv'

powercap6_1 =  'pc1/_float_PowerLimit___1.csv'
powercap6_12 = 'pc1/_float_PowerLimit__12.csv'
powercap6_15 = 'pc1/_float_PowerLimit__15.csv'
powercap6_25 = 'pc1/_float_PowerLimit__25.csv'
powercap6_47 = 'pc1/_float_PowerLimit__47.csv'
powercap6_55 = 'pc1/_float_PowerLimit__55.csv'

powercap7_1 =  'pc1/_genshi_PowerLimit___1.csv'
powercap7_12 = 'pc1/_genshi_PowerLimit__12.csv'
powercap7_15 = 'pc1/_genshi_PowerLimit__15.csv'
powercap7_25 = 'pc1/_genshi_PowerLimit__25.csv'
powercap7_47 = 'pc1/_genshi_PowerLimit__47.csv'
powercap7_55 = 'pc1/_genshi_PowerLimit__55.csv'

powercap8_1 =  'pc1/_json_dumps_PowerLimit___1.csv'
powercap8_12 = 'pc1/_json_dumps_PowerLimit__12.csv'
powercap8_15 = 'pc1/_json_dumps_PowerLimit__15.csv'
powercap8_25 = 'pc1/_json_dumps_PowerLimit__25.csv'
powercap8_47 = 'pc1/_json_dumps_PowerLimit__47.csv'
powercap8_55 = 'pc1/_json_dumps_PowerLimit__55.csv'

powercap9_1 =  'pc1/_json_loads_PowerLimit___1.csv'
powercap9_12 = 'pc1/_json_loads_PowerLimit__12.csv'
powercap9_15 = 'pc1/_json_loads_PowerLimit__15.csv'
powercap9_25 = 'pc1/_json_loads_PowerLimit__25.csv'
powercap9_47 = 'pc1/_json_loads_PowerLimit__47.csv'
powercap9_55 = 'pc1/_json_loads_PowerLimit__55.csv'


# Read CSV file into a DataFrame
df_powercap_1_1 = pd.read_csv (powercap_1 , names=columns, skiprows=1)
df_powercap_1_12 = pd.read_csv(powercap_12, names=columns, skiprows=1)
df_powercap_1_15 = pd.read_csv(powercap_15, names=columns, skiprows=1)
df_powercap_1_25 = pd.read_csv(powercap_25, names=columns, skiprows=1)
df_powercap_1_47 = pd.read_csv(powercap_47, names=columns, skiprows=1)
df_powercap_1_55 = pd.read_csv(powercap_55, names=columns, skiprows=1)

df_powercap_2_1 = pd.read_csv (powercap2_1 , names=columns, skiprows=1)
df_powercap_2_12 = pd.read_csv(powercap2_12, names=columns, skiprows=1)
df_powercap_2_15 = pd.read_csv(powercap2_15, names=columns, skiprows=1)
df_powercap_2_25 = pd.read_csv(powercap2_25, names=columns, skiprows=1)
df_powercap_2_47 = pd.read_csv(powercap2_47, names=columns, skiprows=1)
df_powercap_2_55 = pd.read_csv(powercap2_55, names=columns, skiprows=1)


df_powercap_3_1 = pd.read_csv (powercap3_1 , names=columns, skiprows=1)
df_powercap_3_12 = pd.read_csv(powercap3_12, names=columns, skiprows=1)
df_powercap_3_15 = pd.read_csv(powercap3_15, names=columns, skiprows=1)
df_powercap_3_25 = pd.read_csv(powercap3_25, names=columns, skiprows=1)
df_powercap_3_47 = pd.read_csv(powercap3_47, names=columns, skiprows=1)
df_powercap_3_55 = pd.read_csv(powercap3_55, names=columns, skiprows=1)

df_powercap_4_1 = pd.read_csv (powercap4_1 , names=columns, skiprows=1)
df_powercap_4_12 = pd.read_csv(powercap4_12, names=columns, skiprows=1)
df_powercap_4_15 = pd.read_csv(powercap4_15, names=columns, skiprows=1)
df_powercap_4_25 = pd.read_csv(powercap4_25, names=columns, skiprows=1)
df_powercap_4_47 = pd.read_csv(powercap4_47, names=columns, skiprows=1)
df_powercap_4_55 = pd.read_csv(powercap4_55, names=columns, skiprows=1)

df_powercap_5_1 = pd.read_csv (powercap5_1 , names=columns, skiprows=1)
df_powercap_5_12 = pd.read_csv(powercap5_12, names=columns, skiprows=1)
df_powercap_5_15 = pd.read_csv(powercap5_15, names=columns, skiprows=1)
df_powercap_5_25 = pd.read_csv(powercap5_25, names=columns, skiprows=1)
df_powercap_5_47 = pd.read_csv(powercap5_47, names=columns, skiprows=1)
df_powercap_5_55 = pd.read_csv(powercap5_55, names=columns, skiprows=1)

df_powercap_6_1 = pd.read_csv (powercap6_1 , names=columns, skiprows=1)
df_powercap_6_12 = pd.read_csv(powercap6_12, names=columns, skiprows=1)
df_powercap_6_15 = pd.read_csv(powercap6_15, names=columns, skiprows=1)
df_powercap_6_25 = pd.read_csv(powercap6_25, names=columns, skiprows=1)
df_powercap_6_47 = pd.read_csv(powercap6_47, names=columns, skiprows=1)
df_powercap_6_55 = pd.read_csv(powercap6_55, names=columns, skiprows=1)

df_powercap_7_1 = pd.read_csv (powercap7_1 , names=columns, skiprows=1)
df_powercap_7_12 = pd.read_csv(powercap7_12, names=columns, skiprows=1)
df_powercap_7_15 = pd.read_csv(powercap7_15, names=columns, skiprows=1)
df_powercap_7_25 = pd.read_csv(powercap7_25, names=columns, skiprows=1)
df_powercap_7_47 = pd.read_csv(powercap7_47, names=columns, skiprows=1)
df_powercap_7_55 = pd.read_csv(powercap7_55, names=columns, skiprows=1)

df_powercap_8_1 = pd.read_csv (powercap8_1 , names=columns, skiprows=1)
df_powercap_8_12 = pd.read_csv(powercap8_12, names=columns, skiprows=1)
df_powercap_8_15 = pd.read_csv(powercap8_15, names=columns, skiprows=1)
df_powercap_8_25 = pd.read_csv(powercap8_25, names=columns, skiprows=1)
df_powercap_8_47 = pd.read_csv(powercap8_47, names=columns, skiprows=1)
df_powercap_8_55 = pd.read_csv(powercap8_55, names=columns, skiprows=1)

df_powercap_9_1 = pd.read_csv (powercap9_1 , names=columns, skiprows=1)
df_powercap_9_12 = pd.read_csv(powercap9_12, names=columns, skiprows=1)
df_powercap_9_15 = pd.read_csv(powercap9_15, names=columns, skiprows=1)
df_powercap_9_25 = pd.read_csv(powercap9_25, names=columns, skiprows=1)
df_powercap_9_47 = pd.read_csv(powercap9_47, names=columns, skiprows=1)
df_powercap_9_55 = pd.read_csv(powercap_55, names=columns, skiprows=1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_powercap_1_1, df_powercap_1_12, etc. are DataFrames containing the data

# Calculate means for each program and power limit combination (Time in milliseconds)
async_tree_cpu_io_mixed_time_means = [
    df_powercap_1_1['Time (ms)'].mean(),
    df_powercap_1_12['Time (ms)'].mean(),
    df_powercap_1_15['Time (ms)'].mean(),
    df_powercap_1_25['Time (ms)'].mean(),
    df_powercap_1_47['Time (ms)'].mean(),
    df_powercap_1_55['Time (ms)'].mean()
    
]

async_tree_time_means = [
    df_powercap_2_1['Time (ms)'].mean(),
    df_powercap_2_12['Time (ms)'].mean(),
    df_powercap_2_15['Time (ms)'].mean(),
    df_powercap_2_25['Time (ms)'].mean(),
    df_powercap_2_47['Time (ms)'].mean(),
    df_powercap_2_55['Time (ms)'].mean()
]

chameleon_time_means = [
    df_powercap_3_1['Time (ms)'].mean(),
    df_powercap_3_12['Time (ms)'].mean(),
    df_powercap_3_15['Time (ms)'].mean(),
    df_powercap_3_25['Time (ms)'].mean(),
    df_powercap_3_47['Time (ms)'].mean(),
    df_powercap_3_55['Time (ms)'].mean()
]

django_time_means = [
    df_powercap_4_1['Time (ms)'].mean(),
    df_powercap_4_12['Time (ms)'].mean(),
    df_powercap_4_15['Time (ms)'].mean(),
    df_powercap_4_25['Time (ms)'].mean(),
    df_powercap_4_47['Time (ms)'].mean(),
    df_powercap_4_55['Time (ms)'].mean()
]

docutils_time_means = [
    df_powercap_5_1['Time (ms)'].mean(),
    df_powercap_5_12['Time (ms)'].mean(),
    df_powercap_5_15['Time (ms)'].mean(),
    df_powercap_5_25['Time (ms)'].mean(),
    df_powercap_5_47['Time (ms)'].mean(),
    df_powercap_5_55['Time (ms)'].mean()
]

float_time_means = [
    df_powercap_6_1['Time (ms)'].mean(),
    df_powercap_6_12['Time (ms)'].mean(),
    df_powercap_6_15['Time (ms)'].mean(),
    df_powercap_6_25['Time (ms)'].mean(),
    df_powercap_6_47['Time (ms)'].mean(),
    df_powercap_6_55['Time (ms)'].mean()
]

genshi_time_means = [
    df_powercap_7_1['Time (ms)'].mean(),
    df_powercap_7_12['Time (ms)'].mean(),
    df_powercap_7_15['Time (ms)'].mean(),
    df_powercap_7_25['Time (ms)'].mean(),
    df_powercap_7_47['Time (ms)'].mean(),
    df_powercap_7_55['Time (ms)'].mean()
]

json_dumps_time_means = [
    df_powercap_8_1['Time (ms)'].mean(),
    df_powercap_8_12['Time (ms)'].mean(),
    df_powercap_8_15['Time (ms)'].mean(),
    df_powercap_8_25['Time (ms)'].mean(),
    df_powercap_8_47['Time (ms)'].mean(),
    df_powercap_8_55['Time (ms)'].mean()
]

json_loads_time_means = [
    df_powercap_9_1['Time (ms)'].mean(),
    df_powercap_9_12['Time (ms)'].mean(),
    df_powercap_9_15['Time (ms)'].mean(),
    df_powercap_9_25['Time (ms)'].mean(),
    df_powercap_9_47['Time (ms)'].mean(),
    df_powercap_9_55['Time (ms)'].mean()
]



# Set up bar chart parameters
bar_width = 0.08
bar_positions = np.arange(6)

# Plot bar chart
plt.bar(bar_positions - 4.5*bar_width, async_tree_cpu_io_mixed_time_means, width=bar_width, label='Async_tree_cpu_io_mixed')
plt.bar(bar_positions - 3.5*bar_width, async_tree_time_means, width=bar_width, label='Async_tree')
plt.bar(bar_positions - 2.5*bar_width, chameleon_time_means, width=bar_width, label='Chameleon')
plt.bar(bar_positions - 1.5*bar_width, django_time_means, width=bar_width, label='Django')
plt.bar(bar_positions - 0.5*bar_width, docutils_time_means, width=bar_width, label='Docutils')
plt.bar(bar_positions + 0.5*bar_width, float_time_means, width=bar_width, label='Float')
plt.bar(bar_positions + 1.5*bar_width, genshi_time_means, width=bar_width, label='Genshi')
plt.bar(bar_positions + 2.5*bar_width, json_dumps_time_means, width=bar_width, label='Json_Dumps')
plt.bar(bar_positions + 3.5*bar_width, json_loads_time_means, width=bar_width, label='Json_Loads')



# Set labels and title
plt.ylabel('Mean Time (ms)')
plt.title('Execution Time per Program and Power Limit')
plt.legend(title='Program')
plt.xticks(bar_positions, ['Power Limit -1', 'Power Limit 12', 'Power Limit 15', 'Power Limit 25', 'Power Limit 47', 'Power Limit 55'], rotation=45)

# Show the plot
plt.show()
